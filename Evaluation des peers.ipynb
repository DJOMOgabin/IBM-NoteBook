# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b> NKUIGWA DJOMO GABIN <b>

# %% [markdown]
# BUSINESS ANALYST

# %% [markdown]
# <i>I am interested in data science because it's my passion since many more years now and also to grow my skils.<i>

# %% [markdown]
# ### It must be executed and must display an output

# %%
total = 0
for num in (-22.0, 3.5, 8.1, -10, 0.5):
    if num > 0:
        total = total + total*num
    else:
        total = total + num
        
total
# Out:
# -1366.35

# %% [markdown]
# ***
# <ul>
#     <li> Item 1 </li>
#     <li> Item 2 </li>
#     <li> Item 3 </li>
#     <li> Item 4 </li>
#     <li> Item 5 </li>
# </ul>
#
# ***
#
# <ol>
#     <li> First </li>
#     <li> Second </li>
#     <li> Third </li>
#     <li> Fourth </li>
#     <li> Fifth </li>
# </ol>
#
# ***
#
# <table>
#   <tr>
#     <th>Company</th>
#     <th>Contact</th>
#     <th>Country</th>
#   </tr>
#   <tr>
#     <td>Alfreds Futterkiste</td>
#     <td>Maria Anders</td>
#     <td>Germany</td>
#   </tr>
#   <tr>
#     <td>Centro comercial Moctezuma</td>
#     <td>Francisco Chang</td>
#     <td>Mexico</td>
#   </tr>
# </table>
#
# ***
#
# <a href="https://google.com">Google</a>

# %% [markdown]
# <i>This is the link to go to my Jupyter Notebook on IBM Watson Studio an see what I do
# <a href="https://dataplatform.cloud.ibm.com/analytics/notebooks/v2/a0748269-681c-48e2-a567-073c94eb9afb/view?access_token=2aa53b782d88dbde1318500fe9f2044f8ec1a6842930037303bef49213349898">
# Link of my Jupyter Notebook on IBM Watson Studio
# </a>
# </i>
